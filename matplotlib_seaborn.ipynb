# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.5em; color:#00b3e5;"> Matplotlib

# %% [markdown]
# ![matplotlib-2.png](attachment:matplotlib-2.png)

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> plot(x, y)

# %%
import matplotlib.pyplot as plt
import numpy as np

# make data
x  = np.linspace(0, 10, 50)
y1 = 4 + 2 * np.sin(2 * x)
y2 = 4 - 2 * np.sin(2 * x)

# %%
# plot
plt.style.use('_mpl-gallery')

fig, ax = plt.subplots( figsize=(7,2) )

ax.plot(x, y1, color='blue', marker='o', markersize=5, linestyle='',  linewidth=2.0)
ax.plot(x, y2, color='red',  marker='',  markersize=5, linestyle='-', linewidth=2.0)

ax.set(title='plot(x,y)', xlabel='X', ylabel='Y',
       xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

ax.grid(False)
plt.show()

# %%
# plot
plt.style.use('_mpl-gallery')

plt.subplot(2,1,1)
plt.plot(x, y1, color='blue', linestyle='-.', linewidth=2.0) 
plt.title('plot(x,y)')
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(0, 8)
plt.ylim(0, 8)
plt.xticks(np.arange(1, 8))
plt.yticks(np.arange(1, 8)) 
plt.grid(False)

plt.subplot(2,1,2)
plt.plot(x, y2, color='red',  linestyle='-',  linewidth=2.0)
plt.title('plot(x,y)')
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(0, 8)
plt.ylim(0, 8)
plt.xticks(np.arange(1, 8))
plt.yticks(np.arange(1, 8)) 
plt.grid(True)

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> scatter(x, y, s, c)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make the data 
np.random.seed(3)
x      = np.random.normal(  0,  2,   24   ) + 4
y      = np.random.normal(  0,  2,  len(x)) + 4
sizes  = np.random.uniform(10, 100, len(x))
colors = np.random.uniform(20, 120, len(x))

# %%
# plot
fig, ax = plt.subplots( figsize=(3,3) )

ax.scatter(x, y, marker='o', s=sizes, c=colors, vmin=0, vmax=100)

ax.set(xlim=(-8, 8), xticks=np.arange(-8, 8, 2),
       ylim=(-8, 8), yticks=np.arange(-8, 8, 2))

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> bar(x, height)

# %%
import matplotlib.pyplot as plt
import numpy as np  

# make data:
np.random.seed(3)
x = 0.5 + np.arange(8)
y = np.random.uniform(2, 7, len(x))

# plot
plt.style.use('_mpl-gallery')

fig, ax = plt.subplots()

ax.bar(x, y, width=1.0, facecolor="cyan", edgecolor="blue", linewidth=0.7)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np  

# make data:
np.random.seed(3)
x = ['c1','c2','c3']
y = [4, 5.0 ,3]

# plot
plt.style.use('_mpl-gallery')

fig, ax = plt.subplots()

ax.bar(x, y, width=0.8, facecolor="cyan", edgecolor="blue", linewidth=0.7)

# manual
ax.set(title='Bar(x,y)', xlabel='X', ylabel='Y')
ax.set(ylim=(0, int(max(y)+1)))
ax.set(yticks=np.arange(2, int(max(y)+2), 2))

# auto
ax.set( xlim=(-1, len(x)) )
ax.set( xticks=x )
ax.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np  

# make data:
np.random.seed(3)
x = ['c1','c2','c3']
y = [4, 5.0 ,3]

# plot
plt.style.use('_mpl-gallery')

fig, ax = plt.subplots()

ax.barh(x, y, facecolor="cyan", edgecolor="blue", linewidth=0.7)

# manual
ax.set(title='BarH(x,y)', xlabel='Y', ylabel='X')
ax.set(xlim=(0, int(max(y)+1)))
ax.set(xticks=np.arange(2, int(max(y)+2), 2))

# auto
ax.set( ylim=(-1, len(x)) )
ax.set( yticks=x )
ax.grid(True)

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> stem(x, y)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
np.random.seed(3)
x = 0.5 + np.arange(8)
y = np.random.uniform(2, 7, len(x))

# plot
fig, ax = plt.subplots()

ax.stem(x, y)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> step(x, y)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
np.random.seed(3)
x = 0.5 + np.arange(8)
y = np.random.uniform(2, 7, len(x))

# plot
fig, ax = plt.subplots()

ax.step(x, y, linewidth=2.5)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> fill_between(x, y1, y2)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
np.random.seed(1)
x = np.linspace(0, 8, 16)
y1 = 3 + 4*x/8 + np.random.uniform(0.0, 0.5, len(x))
y2 = 1 + 2*x/8 + np.random.uniform(0.0, 0.5, len(x))

# plot
fig, ax = plt.subplots()

ax.fill_between(x, y1, y2, alpha=.5, linewidth=0)
ax.plot(x, (y1 + y2)/2, linewidth=2)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> stackplot(x, y)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
x = np.arange(0, 10, 2)
ay = [1, 1.25, 2, 2.75, 3]
by = [1, 1, 1, 1, 1]
cy = [2, 1, 2, 1, 2]
y = np.vstack([ay, by, cy])

# plot
fig, ax = plt.subplots()

ax.stackplot(x, y)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:green;"> imshow(Z)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data
X, Y = np.meshgrid(np.linspace(-3, 3, 128), np.linspace(-3, 3, 128))
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)

# plot
fig, ax = plt.subplots()

ax.imshow(Z)

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:green;"> pcolormesh(X, Y, Z)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data with uneven sampling in x
x = [-3, -2, -1.6, -1.2, -.8, -.5, -.2, .1, .3, .5, .8, 1.1, 1.5, 1.9, 2.3, 3]
X, Y = np.meshgrid(x, np.linspace(-3, 3, 128))
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)

# plot
fig, ax = plt.subplots()

ax.pcolormesh(X, Y, Z, vmin=-0.5, vmax=1.0)

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:green;"> contour(X, Y, Z)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data
X, Y = np.meshgrid(np.linspace(-3, 3, 256), np.linspace(-3, 3, 256))
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)
levels = np.linspace(np.min(Z), np.max(Z), 7)

# plot
fig, ax = plt.subplots()

ax.contour(X, Y, Z, levels=levels)

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:green;"> contourf(X, Y, Z)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data
X, Y = np.meshgrid(np.linspace(-3, 3, 256), np.linspace(-3, 3, 256))
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)
levels = np.linspace(Z.min(), Z.max(), 7)

# plot
fig, ax = plt.subplots()

ax.contourf(X, Y, Z, levels=levels)

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:green;"> barbs(X, Y, U, V)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data:
X, Y = np.meshgrid([1, 2, 3, 4], [1, 2, 3, 4])
angle = np.pi / 180 * np.array([[15., 30, 35, 45],
                                [25., 40, 55, 60],
                                [35., 50, 65, 75],
                                [45., 60, 75, 90]])
amplitude = np.array([[5, 10, 25, 50],
                      [10, 15, 30, 60],
                      [15, 26, 50, 70],
                      [20, 45, 80, 100]])
U = amplitude * np.sin(angle)
V = amplitude * np.cos(angle)

# plot:
fig, ax = plt.subplots()

ax.barbs(X, Y, U, V, barbcolor='C0', flagcolor='C0', length=7, linewidth=1.5)

ax.set(xlim=(0, 4.5), ylim=(0, 4.5))

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:green;"> quiver(X, Y, U, V)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data
x = np.linspace(-4, 4, 6)
y = np.linspace(-4, 4, 6)
X, Y = np.meshgrid(x, y)
U = X + Y
V = Y - X

# plot
fig, ax = plt.subplots()

ax.quiver(X, Y, U, V, color="C0", angles='xy',
          scale_units='xy', scale=5, width=.015)

ax.set(xlim=(-5, 5), ylim=(-5, 5))

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:green;"> streamplot(X, Y, U, V)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make a stream function:
X, Y = np.meshgrid(np.linspace(-3, 3, 256), np.linspace(-3, 3, 256))
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)
# make U and V out of the streamfunction:
V = np.diff(Z[1:, :], axis=1)
U = -np.diff(Z[:, 1:], axis=0)

# plot:
fig, ax = plt.subplots()

ax.streamplot(X[1:, 1:], Y[1:, 1:], U, V)

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> hist(x)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
np.random.seed(1)
x = 4 + np.random.normal(0, 1.5, 200)

# plot:
fig, ax = plt.subplots()

ax.hist(x, bins=8, linewidth=1, edgecolor='blue', facecolor='cyan')

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> boxplot(X)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data:
np.random.seed(10)
D = np.random.normal((3, 5, 4), (1.25, 1.00, 1.25), (100, 3))

# plot
fig, ax = plt.subplots()
VP = ax.boxplot(D, positions=[2, 4, 6], widths=1.5, 
                patch_artist=True, showmeans=True, showfliers=True,
                medianprops={"color": "blue", "linewidth": 0.5},
                boxprops={"facecolor": "cyan", "edgecolor": "blue", "linewidth": 0.5},
                whiskerprops={"color": "lime", "linewidth": 1.5},
                capprops={"color": "black", "linewidth": 1.5})

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> errorbar(x, y, yerr, xerr)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data:
np.random.seed(1)
x = [2, 4, 6]
y = [3.6, 5, 4.2]
yerr = [0.9, 1.2, 0.5]

# plot:
fig, ax = plt.subplots()

ax.errorbar(x, y, yerr, fmt='o', linewidth=2, capsize=6)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> violinplot(D)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data:
np.random.seed(10)
D = np.random.normal((3, 5, 4), (0.75, 1.00, 0.75), (200, 3))

# plot:
fig, ax = plt.subplots()

vp = ax.violinplot(D, [2, 4, 6], widths=2,
                   showmeans=True, showmedians=True, showextrema=True)
# styling:
for body in vp['bodies']:
    body.set_alpha(0.5)
ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> eventplot(D)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data:
np.random.seed(1)
x = [2, 4, 6]
D = np.random.gamma(4, size=(3, 50))

# plot:
fig, ax = plt.subplots()

ax.eventplot(D, orientation="vertical", lineoffsets=x, linewidth=0.75)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> hist2d(x, y)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data: correlated + noise
np.random.seed(1)
x = np.random.randn(5000)
y = 1.2 * x + np.random.randn(5000) / 3

# plot:
fig, ax = plt.subplots()

ax.hist2d(x, y, bins=(np.arange(-3, 3, 0.1), np.arange(-3, 3, 0.1)))

ax.set(xlim=(-2, 2), ylim=(-3, 3))

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> hexbin(x, y, C)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data: correlated + noise
np.random.seed(1)
x = np.random.randn(5000)
y = 1.2 * x + np.random.randn(5000) / 3

# plot:
fig, ax = plt.subplots()

ax.hexbin(x, y, gridsize=20)

ax.set(xlim=(-2, 2), ylim=(-3, 3))

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> pie(x)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')


# make data

x = ['c1', 'c2', 'c3', 'c4']
y = [1, 2, 3, 4]
colors = plt.get_cmap('Blues')(np.linspace(0.2, 0.7, len(x)))

# plot
fig, ax = plt.subplots()
ax.pie(y, labels=x, autopct='%.1f%%',
       colors=colors, radius=3, center=(4, 4),
       wedgeprops={"linewidth": 1, "edgecolor": "white"}, frame=False)

ax.set(xlim=(0, 4), 
       ylim=(0, 4))

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:green;"> tricontour(x, y, z)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data:
np.random.seed(1)
x = np.random.uniform(-3, 3, 256)
y = np.random.uniform(-3, 3, 256)
z = (1 - x/2 + x**5 + y**3) * np.exp(-x**2 - y**2)
levels = np.linspace(z.min(), z.max(), 7)

# plot:
fig, ax = plt.subplots()

ax.plot(x, y, 'o', markersize=2, color='lightgrey')
ax.tricontour(x, y, z, levels=levels)

ax.set(xlim=(-3, 3), ylim=(-3, 3))

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:green;"> tricontourf(x, y, z)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data:
np.random.seed(1)
x = np.random.uniform(-3, 3, 256)
y = np.random.uniform(-3, 3, 256)
z = (1 - x/2 + x**5 + y**3) * np.exp(-x**2 - y**2)
levels = np.linspace(z.min(), z.max(), 7)

# plot:
fig, ax = plt.subplots()

ax.plot(x, y, 'o', markersize=2, color='grey')
ax.tricontourf(x, y, z, levels=levels)

ax.set(xlim=(-3, 3), ylim=(-3, 3))

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:green;"> tripcolor(x, y, z)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data:
np.random.seed(1)
x = np.random.uniform(-3, 3, 256)
y = np.random.uniform(-3, 3, 256)
z = (1 - x/2 + x**5 + y**3) * np.exp(-x**2 - y**2)

# plot:
fig, ax = plt.subplots()

ax.plot(x, y, 'o', markersize=2, color='grey')
ax.tripcolor(x, y, z)

ax.set(xlim=(-3, 3), ylim=(-3, 3))

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:green;"> triplot(x, y)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data:
np.random.seed(1)
x = np.random.uniform(-3, 3, 256)
y = np.random.uniform(-3, 3, 256)
z = (1 - x/2 + x**5 + y**3) * np.exp(-x**2 - y**2)

# plot:
fig, ax = plt.subplots()

ax.triplot(x, y)

ax.set(xlim=(-3, 3), ylim=(-3, 3))

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> 3D scatterplot

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# Make data
np.random.seed(19680801)
n = 100
rng = np.random.default_rng()
xs = rng.uniform(23, 32, n)
ys = rng.uniform(0, 100, n)
zs = rng.uniform(-50, -25, n)

# Plot
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.scatter(xs, ys, zs, c='green')

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> 3D surface

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

plt.style.use('_mpl-gallery')

# Make data
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_surface(X, Y, Z, vmin=Z.min() * 2, cmap=cm.Blues)

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> Triangular 3D surfaces

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

plt.style.use('_mpl-gallery')

n_radii = 8
n_angles = 36

# Make radii and angles spaces
radii = np.linspace(0.125, 1.0, n_radii)
angles = np.linspace(0, 2*np.pi, n_angles, endpoint=False)[..., np.newaxis]

# Convert polar (radii, angles) coords to cartesian (x, y) coords.
x = np.append(0, (radii*np.cos(angles)).flatten())
y = np.append(0, (radii*np.sin(angles)).flatten())
z = np.sin(-x*y)

# Plot
fig, ax = plt.subplots(subplot_kw={'projection': '3d'})
ax.plot_trisurf(x, y, z, vmin=z.min() * 2, cmap=cm.Blues)

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> 3D voxel / volumetric plot

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# Prepare some coordinates
x, y, z = np.indices((8, 8, 8))

# Draw cuboids in the top left and bottom right corners
cube1 = (x < 3) & (y < 3) & (z < 3)
cube2 = (x >= 5) & (y >= 5) & (z >= 5)

# Combine the objects into a single boolean array
voxelarray = cube1 | cube2

# Plot
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.voxels(voxelarray, edgecolor='k')

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> 3D wireframe plot

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

plt.style.use('_mpl-gallery')

# Make data
X, Y, Z = axes3d.get_test_data(0.05)

# Plot
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()

# %% [markdown]
# #####

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.5em; color:violet;"> Seaborn

# %% [markdown]
# ![seaborn.png](attachment:seaborn.png)

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:violet;"> # lineplot( x, y, hue, style )

# %%
import matplotlib.pyplot as plt
#plt.style.use('_mpl-gallery')

import seaborn as sns

fmri = sns.load_dataset('fmri')
fmri.head(3)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033

# %%
sns.set(rc={'figure.figsize':(13,5)})
sns.set(style='whitegrid')

sns_plot = sns.lineplot( x='timepoint', y='signal', data=fmri,
                         hue='event', style='event', markers=True )

sns_plot.set( title="lineplot" )
fig = sns_plot.get_figure() 
#fig.savefig('lineplot.png')
plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:violet;"> scatterplot( x, y, hue, style )

# %%
import matplotlib.pyplot as plt
#plt.style.use('_mpl-gallery')

import seaborn as sns

fmri = sns.load_dataset('fmri')
fmri.head(3)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033

# %%
sns.set(rc={'figure.figsize':(13,5)})
sns.set(style='whitegrid')

sns_plot = sns.scatterplot( x='timepoint', y='signal', data=fmri,
                            hue='event', style='region', markers=True )

sns_plot.set( title="scatterplot" )
fig = sns_plot.get_figure() 
#fig.savefig('scatterplot.png')
plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:violet;"> barlot( x, y, hue )

# %%
import matplotlib.pyplot as plt
#plt.style.use('_mpl-gallery')

import seaborn as sns

fmri = sns.load_dataset('fmri')
fmri.head(3)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033

# %%
sns.set(rc={'figure.figsize':(13,5)})
sns.set(style='whitegrid')

sns_plot = sns.barplot( x='region', y='signal', data=fmri, hue='event',
                        palette='Set1' )   # Set1  Set2  Set3  rocket  vlag  blues_d 

sns_plot.set( title="barplot" )
fig = sns_plot.get_figure() 
#fig.savefig('barplot.png')
plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:violet;"> distplot( df[ft] )

# %%
import matplotlib.pyplot as plt
#plt.style.use('_mpl-gallery')

import seaborn as sns

fmri = sns.load_dataset('fmri')
fmri.head(3)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033

# %%
sns.set(rc={'figure.figsize':(13,5)})
sns.set(style='whitegrid')

sns_plot = sns.distplot( fmri['signal'], bins=16, color='green',
                         hist=True, kde=True, vertical=True )
sns_plot.set( title="distplot" )

fig = sns_plot.get_figure() 
fig.savefig('distplot.png')

plt.show()
# Out:
# C:\Users\EZ-Tech\AppData\Local\Temp\ipykernel_11496\43072940.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns_plot = sns.distplot( fmri['signal'], bins=16, color='green',

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:violet;"> jointplot( x, y )

# %%
import matplotlib.pyplot as plt
#plt.style.use('_mpl-gallery')

import seaborn as sns

fmri = sns.load_dataset('fmri')
fmri.head(3)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033

# %%
#sns.set(style='whitegrid')
sns_plot = sns.jointplot( x='timepoint', y='signal', data=fmri, color='green',
                          kind='reg' )

#sns_plot.savefig('jointplot.png')
plt.show()

# %%
#sns.set(style='whitegrid')
sns_plot = sns.jointplot( x='timepoint', y='signal', data=fmri, color='green', edgecolor='k',
                          kind='scatter', alpha=0.35 )

#sns_plot.savefig('jointplot.png')
plt.show()

# %%
#sns.set(style='whitegrid')
sns_plot = sns.jointplot( x='timepoint', y='signal', data=fmri, color='green',
                          kind='kde' )

#sns_plot.savefig('jointplot.png')
plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:violet;"> boxplot( x, y, hue )

# %%
import matplotlib.pyplot as plt
#plt.style.use('_mpl-gallery')

import seaborn as sns

fmri = sns.load_dataset('fmri')
fmri.head(3)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033

# %%
sns.set(rc={'figure.figsize':(13,5)})
sns.set(style='whitegrid')

sns_plot = sns.boxplot( x='region', y='signal', data=fmri, hue='event',
                        #order=['frontal', 'parietal'],  # order of x 
                        linewidth=1.0, 
                        palette='Set1' )  # Set1  Set2  Set3  rocket  vlag  blues_d  

sns_plot.set( title="boxplot" )
fig = sns_plot.get_figure() 
#fig.savefig('boxplot.png')
plt.show()

# %%
sns.set(rc={'figure.figsize':(13,5)})
sns.set(style='whitegrid')

boxprops    = dict( edgecolor='k', linewidth=1 ) #, facecolor='cyan' 
medianprops = dict( color='k', linewidth=1 )
flierprops  = dict( markersize=7, markerfacecolor='red', markeredgecolor='red', marker='d' ) # 'd', 'x'

sns_plot = sns.boxplot( x='region', y='signal', data=fmri, hue='event',
                        #order=['frontal', 'parietal'],  # order of x 
                        linewidth   = 1.0, 
                        palette     = 'Set1',   # Set1  Set2  Set3  rocket  vlag  blues_d 
                        boxprops    = boxprops,
                        medianprops = medianprops,
                        flierprops  = flierprops  )

sns_plot.set( title="boxplot" )
fig = sns_plot.get_figure() 
#fig.savefig('boxplot.png')
plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:violet;"> countplot( x, hue )

# %%
import matplotlib.pyplot as plt
#plt.style.use('_mpl-gallery')

import seaborn as sns

fmri = sns.load_dataset('fmri')
fmri.head(3)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033

# %%
sns.set(rc={'figure.figsize':(13,3.5)})
sns.set(style='whitegrid')

#sns_plot = sns.countplot( x=fmri['event'], hue=fmri['region'], palette='Set1' )
sns_plot = sns.countplot( x='event', hue='region', data=fmri, palette='Set1' )
sns_plot.set( title="countplot" )

total = float( fmri.shape[0] )
for p in sns_plot.patches:
    height=p.get_height()
    sns_plot.text(p.get_x()+p.get_width()/2.,height+3,'{0:.0%}'.format(height/total),ha='center')

fig = sns_plot.get_figure() 
#fig.savefig('countplot.png')
plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:violet;"> heatmap( corr )

# %%
import numpy as np

import matplotlib.pyplot as plt
#plt.style.use('_mpl-gallery')

import seaborn as sns

fmri = sns.load_dataset('fmri')
fmri.head(3)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033

# %%
sc_cols = ['timepoint','signal']
corr = fmri[sc_cols].corr('pearson')

sns.set(style='whitegrid')
_,ax = plt.subplots(figsize=(3,3))
sns_plot = sns.heatmap( corr, mask=np.zeros_like(corr,dtype=bool),
                        cmap=sns.diverging_palette(220,10,as_cmap=True),
                        square=True, ax=ax, annot=True, center=0.00 )

sns_plot.set( title="heatmap" )
fig = sns_plot.get_figure() 
#fig.savefig('heatmap.png')
plt.show()

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:violet;"> swarmplot

# %%
import numpy as np

import matplotlib.pyplot as plt
#plt.style.use('_mpl-gallery')

import seaborn as sns

fmri = sns.load_dataset('fmri')
fmri.head(3)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033

# %%
# swarmplot
df   = fmri.dropna()
sclr = 'signal'    # y
cat1 = 'subject'   # x
cat2 = 'region' 

plt.figure(figsize=(12,5))
sns_plot = sns.swarmplot( data=df, x=cat2, y=sclr, hue=cat1, palette='Set2', s=4 )
sns.despine(); plt.show()

# %% [markdown]
# #####

# %%
# swarmplot
df = fmri.dropna()
sclr1 = 'timepoint' # x
sclr2 = 'signal'    # y
cat   = 'region'

plt.figure(figsize=(12,5))
sns_plot = sns.swarmplot( data=df, x=sclr1, y=sclr2, hue=cat, palette='Set2', s=3 )
sns.despine(); plt.show()
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\categorical.py:3370: UserWarning: 7.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:violet;"> stripplot

# %%
import numpy as np

import matplotlib.pyplot as plt
#plt.style.use('_mpl-gallery')

import seaborn as sns

fmri = sns.load_dataset('fmri')
fmri.head(3)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033

# %%
# stripplot
df   = fmri.dropna()
sclr = 'signal'    # y
cat1 = 'subject'   # x
cat2 = 'region'    

plt.figure(figsize=(12,5))
sns_plot = sns.stripplot( data=df, y=sclr, x=cat2, hue=cat1, palette='Set2', s=10, jitter=0.3, legend=True )
sns.despine(); plt.show()

# %% [markdown]
# #####

# %%
# stripplot
df = fmri.dropna()
sclr1 = 'timepoint' # x
sclr2 = 'signal'    # y
cat   = 'region'

plt.figure(figsize=(12,5))
sns_plot = sns.stripplot( data=df, x=sclr1, y=sclr2, hue=cat, palette='Set2', s=7, jitter=0.3, legend=True )
sns.despine(); plt.show()

# %% [markdown]
# #####

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:violet;"> Implot

# %%
import numpy as np

import matplotlib.pyplot as plt
#plt.style.use('_mpl-gallery')

import seaborn as sns

fmri = sns.load_dataset('fmri')
fmri.head(3)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033

# %%
# ImPlot
df = fmri.dropna()
sclr1 = 'timepoint' # x
sclr2 = 'signal'    # y
cat   = 'region'

sns.lmplot( x=sclr1, y=sclr2, data=df, hue=cat, palette='Set2', height=5, aspect=16/9, x_jitter=0.2 ); plt.show()

# %% [markdown]
# #####

# %% [markdown]
# #
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:violet;"> PairPlot

# %%
import numpy as np

import matplotlib.pyplot as plt
#plt.style.use('_mpl-gallery')

import seaborn as sns

fmri = sns.load_dataset('fmri')
fmri.head(3)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033

# %%
df = fmri.dropna()
sclr1 = 'timepoint' # x
sclr2 = 'signal'    # y
cat   = 'region'

# %%
# PairPlot
g = sns.pairplot( df, vars=[sclr1,sclr2], hue=cat, diag_kind='kde', palette='Set2', height=3, aspect=4/3 )
#g._legend.remove() 
plt.show()

# %% [markdown]
# #####

# %% [markdown]
# #####
